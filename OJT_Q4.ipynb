# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
np.random.seed(6)
coefficients = np.random.randn(6)
print(coefficients)
# Out:
# [-0.31178367  0.72900392  0.21782079 -0.8990918  -2.48678065  0.91325152]

# %%
X=np.arange(-5,6.1,0.1)
plt.plot(X,-0.31178367*X**5+0.72900392*X**4+0.21782079*X**3-0.8990918 *X**2-2.48678065*X+0.91325152)
plt.annotate('local maxima',xy=(-4,1450),xytext=(-2,1450),arrowprops=dict(facecolor='black',shrink=0.0))
plt.annotate('local minima',xy=(6,-1400),xytext=(2,-1500),arrowprops=dict(facecolor='black',shrink=0.0))
# Out:
# Text(2, -1500, 'local minima')
